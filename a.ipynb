# %%
import pandas as pd

# Google Sheet URL with export to CSV format
sheet_url = "https://docs.google.com/spreadsheets/d/1jANJ4ebtrrZzkAQZwd2KxE5xuxj_gbKNWDwYFZ-rRx0/export?format=csv&gid=2107133226"

# Read the CSV data into a pandas DataFrame
df = pd.read_csv(sheet_url)

# Display the first few rows
df
# Out:
#     ลำดับ           ประทับเวลา               ที่อยู่อีเมล  \
# 0     1.0  25/4/2025, 19:41:20     patgamer2549@gmail.com
# 1     2.0  25/4/2025, 19:56:46    punchaya.chan@gmail.com
# 2     3.0  25/4/2025, 19:59:21  chiti.choopayak@gmail.com
# 3     4.0  25/4/2025, 19:59:59     cryptokeepto@gmail.com
# 4     5.0  25/4/2025, 20:01:57   studiedbyaumji@gmail.com
# ..    ...                  ...                        ...
# 81    NaN                  NaN                        NaN
# 82    NaN                  NaN                        NaN
# 83    NaN                  NaN                        NaN
# 84    NaN                  NaN                        NaN
# 85    NaN                  NaN                        NaN
#
#    ท่านได้อ่านข้อกำหนดข้างต้นเรียบร้อยแล้ว  \
# 0                                      ใช่
# 1                                      ใช่
# 2                                      ใช่
# 3                                      ใช่
# 4                                      ใช่
# ...
